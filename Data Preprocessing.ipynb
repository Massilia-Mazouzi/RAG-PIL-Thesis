# %%
"""
Step 1 : Extracting all Patient Information Leaflets pdf files from the source ZIP archive into a local folder for further processing
"""

import zipfile
import os

zip_path = r"\Dataa\medicine_notices_fixed.zip"
extract_to = r"\Dataa\unzipped_pdfs"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    pdf_files = [f for f in zip_ref.namelist() if f.endswith(".pdf")]
    for file in pdf_files:
        zip_ref.extract(file, path=extract_to)

# %%
## Confirming how much files are they in the 'unzipped_pdfs' folder 

unzipped_path = r"\Dataa\unzipped_pdfs"
pdfs = [f for f in os.listdir(unzipped_path) if f.endswith(".pdf")]
print(f"Final raw leaflets PDF count: {len(pdfs)}")
# Out:
# Final raw leaflets PDF count: 1921

# %%
"""
Step 2 : Classifying the extracted PDFs into two categories: 
1. PDFs with selectable text (copied to /dataa/selectable_pdfs)
2. Scanned PDFs requiring OCR (processed with OCRmyPDF and saved to /dataa/ocr_pdfs)
"""

import os
import shutil
import fitz  

raw_dir = r"\Dataa\unzipped_pdfs"
ocr_dir = r"Dataa\ocr_pdfs"
selectable_dir = r"Dataa\selectable_pdfs"

os.makedirs(ocr_dir, exist_ok=True)
os.makedirs(selectable_dir, exist_ok=True)

pdf_files = [f for f in os.listdir(raw_dir) if f.endswith(".pdf")]
print(f"Total PDFs found: {len(pdf_files)}")

# Defining the function to determine if a PDF has selectable text
def has_selectable_text(pdf_path, threshold=100):
    try:
        doc = fitz.open(pdf_path)
        text = "".join(page.get_text() for page in doc)
        return len(text.strip()) > threshold
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
        return False

# Processing each PDF
for idx, filename in enumerate(pdf_files, 1):
    print(f"[{idx}/{len(pdf_files)}] Processing: {filename}")
    input_path = os.path.join(raw_dir, filename)
    ocr_path = os.path.join(ocr_dir, filename)
    selectable_path = os.path.join(selectable_dir, filename)

    if has_selectable_text(input_path):
        print("  → Selectable text detected → Copied to selectable_pdfs")
        shutil.copy2(input_path, selectable_path)
    else:
        print("  → No text detected → Running OCR")
        os.system(f'ocrmypdf "{input_path}" "{ocr_path}" --force-ocr --rotate-pages -l fra+eng')

print("Classification complete.")
# Out:
# Total PDFs found: 1924
# [1/1924] Processing: ABASAGLAR 100UI_ML _3_64MG_ML_ SOL_ INJ_ EN STYLO PREREMPLI KWIKPEN  B_05 STYLOS PREREMLIS DE 3 ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [2/1924] Processing: ABILIFY 10MG COMP_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [3/1924] Processing: ABILIFY 15MG COMP_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [4/1924] Processing: ABUFENE 400MG COMP_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [5/1924] Processing: ACARBOSE VIATRIS 50 mg, comprimé_B_99.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [6/1924] Processing: ACEBUTOLOL SANDOZ 200MG COMP_ ENRO_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [7/1924] Processing: ACICLOVIR MYLAN 250MG_FL_ DE PDRE_ PDRE_ SOL_ INJ_ IV B_05 FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [8/1924] Processing: ACICLOVIR MYLAN 500MG_FL_ DE PDRE_ PDRE_ SOL_ INJ_ IV B_05 FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [9/1924] Processing: ACIFIX 175MG_200MG_5ML SUSP_ BUV_ FLACON FL__200ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [10/1924] Processing: ACIFUDAL 0_02 CREME DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [11/1924] Processing: ACLASTA 5MG_100ML SOL INJ P_PERF B_01FL DE 100ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [12/1924] Processing: ACTEMRA 20MG_ML_FLACON  CONCENTRE POUR SOLUTION A DILUER POUR PERFUSION IV  BOITE DE 1 FLACON DE 4 ML _ 80 mg_4ml_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [13/1924] Processing: ACTILYSE 20MG PDRE ET  SOLVT_ SOL_ INJ_ B_1_1.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [14/1924] Processing: ACTILYSE 50MG PDRE ET  SOLVT_ SOL_ INJ_ B_1_1.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [15/1924] Processing: ACTONEL  5MG COMP PELL B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [16/1924] Processing: ACTONEL 35MG COMP PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [17/1924] Processing: ACTRAPID HM 100UI_ML SOL INJ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [18/1924] Processing: ACTRAPID HM PENFILL 100UI_ML SOL INJ_ B_5 CART_ de 1_5 ML ET B_5CART  DE 3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [19/1924] Processing: ACUILIX 20MG_12_5MG COMP _PELLI _SEC B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [20/1924] Processing: ACUITEL 20MG COMP_ ENRO_ SEC_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [21/1924] Processing: ACUITEL 5MG COMP_ ENRO_ SEC_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [22/1924] Processing: ACUPAN 10MG_ML _OU 20MG_2ML_ SOL_ INJ_ IM_IV B_05AMP_ DE 2ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [23/1924] Processing: ADAPALENE NOVAGENERICS 0_001 GEL P_ APPLI_ LOCALE T_30G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [24/1924] Processing: ADCETRIS 50 MG _ ML  POUDRE POUR SOLUTION A DILUER POUR PERFUSION  B_01 FLACON.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [25/1924] Processing: ADEPAL 0_15MG_0_03MG_BLANCS_  ET 0_20MG_0_04MG_ROSE ORANGE_ COMP_ B_3X21_7BLANCS _ 14 ROSE ORANGE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [26/1924] Processing: ADIPINE 20MG GLES_ A µGRLES_  LP B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [27/1924] Processing: ADIPINE-20-Mg_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [28/1924] Processing: ADRENALINE AGUETTANT 0_25MG_ML SOL_INJ_ B_100AMP_ DE 1ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [29/1924] Processing: ADRENALINE AGUETTANT 1MG_ML SOL_INJ_ B_10AMP_ DE 1ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [30/1924] Processing: ADVATE 1000UI_FL DE PDRE  _50UI_ML_  PDRE ET SOLVANT P_SOL INJ IV  B_01FL DE PDRE_01 SERINGUE A USAGE UNIQUE DE 10ML _ 01 FL DE SOLVANT _EPPI_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [31/1924] Processing: ADVATE 250UI_FL DE PDRE _50UI_ML_  PDRE ET SOLVANT P_ SOL INJ IV  B_01FL DE PDRE_01 SERINGUE A USAGE UNIQUE DE 10ML _ 01 FL DE SOLVANT _EPPI_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [32/1924] Processing: ADVATE 500UI_FL DE PDRE _50UI_ML_  PDRE ET SOLVANT P_ SOL INJ IV  B_01FL DE PDRE_01 SERINGUE A USAGE UNIQUE DE 10ML _ 01 FL DE SOLVANT _EPPI_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [33/1924] Processing: AERRANE 100ML_100ML - 250ML_250ML LIQUIDE_ P_ INHAL_ PAR VAPEUR CARTON DE 06 FL_ DE 100ML ET CARTON DE 06 FL_ DE 250ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [34/1924] Processing: AFINITOR 10 MG COMP B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [35/1924] Processing: AFINITOR 5MG COMP B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [36/1924] Processing: AGRASTAT 0_25MG_ML SOL_ A DILUER P_ PERF_ IV B_01FL_ DE 50ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [37/1924] Processing: AIRDITINE 0_5MG_ML SIROP B_1FL_ DE 120ML _ BOUCHON DOSEUR GRADUE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [38/1924] Processing: ALDACTAZINE 25MG_15MG COMP_PELLI_SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [39/1924] Processing: ALDACTONE 75MG COMP_PELLI_SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [40/1924] Processing: ALDOMET 250MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [41/1924] Processing: ALDURAZYME 100U DE LARONIDASE _ML _500U DE LARONIDASE _ML_ SOL_ A DILUER P_ PERF_ IV B_01 FL_ DE 5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [42/1924] Processing: ALIMTA 500MG_FL_ DE PDRE_ PDRE_ LYOPH_ P_ SOL_ A DILUER P_ PERF_ B_01FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [43/1924] Processing: ALKERAN 2MG COMP_ PELLI_ B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [44/1924] Processing: ALLERTINE 10MG COMP_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [45/1924] Processing: ALMIDE 0_1_ COLLY_ FL_ COMPT_ GTTES_ 5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [46/1924] Processing: Alodipine-avec-nouveau-logo.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [47/1924] Processing: ALPROFENE 100MG SUPPO_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [48/1924] Processing: ALZOR 2_ _20MG_ML_ COLLY_ EN SOL_ FL__5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [49/1924] Processing: AMAREL 1 mg, comprimé_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [50/1924] Processing: AMAREL 2 mg, comprimé_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [51/1924] Processing: AMAREL 3 mg, comprimé_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [52/1924] Processing: AMAREL 3MG COMP_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [53/1924] Processing: AMAREL 4 mg, comprimé_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [54/1924] Processing: AMAREL 6MG COMP_ SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [55/1924] Processing: AMBRODAL 0_003 SOL_ BUV_ B_01 FL DE 100 ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [56/1924] Processing: AMIODARONE MYLAN 200MG COMP_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [57/1924] Processing: AMISULPRIDE BEKER 200MG COMP_ SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [58/1924] Processing: AMISULPRIDE BEKER 400MG COMP_ PELLI_ SEC_ B_30.pdf
#   → No text detected → Running OCR
# [59/1924] Processing: AMITRAL 100MG COMP_ DISPERS_  B_30.pdf
#   → No text detected → Running OCR
# [60/1924] Processing: AMITRAL 25MG COMP_ DISPERS_ B_30.pdf
#   → No text detected → Running OCR
# [61/1924] Processing: AMITRAL 5MG COMP_ DISPERS_  B_30.pdf
#   → No text detected → Running OCR
# [62/1924] Processing: AMLODAL 10MG COMP_ SEC_ B_30.pdf
#   → No text detected → Running OCR
# [63/1924] Processing: AMLODAL 5MG COMP B_30.pdf
#   → No text detected → Running OCR
# [64/1924] Processing: AMLODEX-5-mg.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [65/1924] Processing: AMLODIPINE BEKER 10MG GLES B_30 ET B_90.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [66/1924] Processing: AMLODIPINE BEKER 5MG GLES  B_30 ET B_90.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [67/1924] Processing: AMLOR 10MG GLES_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [68/1924] Processing: AMLOR 5MG GLES_ B_28 ET B_98.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [69/1924] Processing: AMOCLAN 8_1 100MG_12_5MG_ML PDRE_ P_ SUSP_ BUV_ ENFANT ET NOURRISSON B_1FL_DE 30ML _NOURRISSON_ - B_1FL_DE 60ML _ENFANT_ DE SUSP_ BUV_ APRES RECONST_ _ PIPETTE GRADUEE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [70/1924] Processing: AMOCLAN 8_1 500MG_62_5MG PDRE_ P_ SUSP_ BUV_ EN SACHET DOSE B_12 ET B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [71/1924] Processing: AMOCLAN BID 400MG_57MG_5ML PDRE_ P_  SUSP_ BUV_ B_1FL_ DE 35ML ET B_1FL_ DE 70ML _DE SUSPENSION BUVABLE APRES RECONSTITUTION_ AVEC PIPIETTE GRADUEE EN KG.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [72/1924] Processing: AMOCLAN BID 875MG_125MG COMP_ PELLI_ PILULIER_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [73/1924] Processing: AMODEX-Gé 250MG_5ML PDRE_ P_ SUSP_ BUV_ FL_60ML.pdf
#   → No text detected → Running OCR
# [74/1924] Processing: AMOXICILLINE _ ACIDE CLAVULANIQUE SANDOZ ADULTE 1G_125MG_SACHET PDRE P_ SUSP_ BUV_ EN SACHET-DOSE B_08 ET B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [75/1924] Processing: AMOXICILLINE _ ACIDE CLAVULANIQUE SANDOZ ADULTE 500MG _ 62_5MG COMP_ PELLI_ B_16 - B_24.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [76/1924] Processing: AMOXYPEN 1G COMP_ DISPER_ B_06 - B_14 - B_16.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [77/1924] Processing: AMOXYPEN 1G_FL_ DE PDRE_ PDRE_ P_ SOL_ INJ_ IM _solvant  LIDOCAINE_ ET IM_IV _sans solvant_ B_1FL_ DE PDRE__1AMP_ DE 5ML DE SOLV_ _ALCOOL BENZYLIQUE 3__ _IM_ ET BOITE DE 50FL_ DE PDRE_SANS SOLV__ _IM_IV_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [78/1924] Processing: AMPILINE   500MG GLES_ B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [79/1924] Processing: AMPINAX 1G_FL_ DE PDRE_ PDRE_ ET SOLV_ P_ SOL_ INJ_ IM_IV B_1FL_ DE PDRE_ _ 1AMP_ DE 5ML DE SOLV_ _EPPI_ ET B_50FL_ DE PDRE_.pdf
#   → No text detected → Running OCR
# [80/1924] Processing: AMPINAX 250MG_5ML PDRE_ P_ SUSP_ BUV_ FL__60ML   _DE SUSP_ BUV_ APRES RECONSTITUTION_.pdf
#   → No text detected → Running OCR
# [81/1924] Processing: AMPINAX 250MG_5ML PDRE_ P_ SUSP_ BUV_FL__100ML  _DE SUSP_ BUV_ APRES RECONSTITUTION_.pdf
#   → No text detected → Running OCR
# [82/1924] Processing: AMPINAX 500MG GLES_ B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [83/1924] Processing: ANAFRANIL 10MG COMP_ENRO_ B_60.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [84/1924] Processing: ANAFRANIL 25MG COMP_ENRO_ B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [85/1924] Processing: ANAFRANIL 25MG_2ML SOL_INJ_ B_05.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [86/1924] Processing: ANAFRANIL 75MG COMP_ENRO_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [87/1924] Processing: Ancea-bebe-FR-sw.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [88/1924] Processing: Ancea_md00-.pdf
#   → No text detected → Running OCR
# [89/1924] Processing: ancefal-1g_500mg_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [90/1924] Processing: ancefal-250-mg-5-ml_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [91/1924] Processing: ANDRIOL TESTOCAPS 40MG CAPS_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [92/1924] Processing: ANDROCUR 50MG COMP_SEC_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [93/1924] Processing: ANDROTARDYL 250MG_ML SOL_INJ_HUIL_ B_1AMP_ DE 1ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [94/1924] Processing: ANESDERM GE 5_ 2_5G_2_5G_100G CREME  T_5G AVEC DEUX PANSEMENTS ADHESIFS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [95/1924] Processing: ANTAG 20MG GLES_ A MICROG_ GASTRORESIST_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [96/1924] Processing: antalfen-200mg-400mg-600mg.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [97/1924] Processing: antalfen-gel_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [98/1924] Processing: antalfen-gyn-100mg.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [99/1924] Processing: antalfen-Sirop-20mg-ml.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [100/1924] Processing: apaisePik-bebe_B_00.pdf
#   → No text detected → Running OCR
# [101/1924] Processing: apaisePik-emulsion_B_00.pdf
#   → No text detected → Running OCR
# [102/1924] Processing: APIDRA 100UI_ML SOL_ INJ_ EN CARTOUCHE SC B_03 CART_  DE 3ML POUR _OPTICLIK OU POUR OPTIPEN_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [103/1924] Processing: APIDRA 100UI_ML SOL_ INJ_ EN FLACON SC B_1FL_DE 10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [104/1924] Processing: APIDRA OPTISET 100UI_ML _3_49MG_ML_ SOL_ INJ_ STYLO PREREMPLI SC B_5 STYLO PREREMPLIS DE 3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [105/1924] Processing: APIDRA SOLOSTAR 100UI_ML _3_49MG_ML_ SOL_ INJ_ EN STYLO PREREMPLI B_05 STYLOS PREREMPLIS SOLOSTAR DE 3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [106/1924] Processing: APROVEL 150MG COMP PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [107/1924] Processing: APROVEL 300MG COMP_ PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [108/1924] Processing: ARANESP 25µG_ML _10µG_0_4ML_ SOL_ INJ_ SC__IV_ EN SERINGUE PREREMPLIE B_04 SERINGUES PREREMPLIES DE 0_4ML SANS SYST_ DE SECURITE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [109/1924] Processing: ARANESP 40µG_ML _20µG_0_5ML_ SOL_ INJ_ SC__IV_ EN SERINGUE PREREMPLIE B_04 SERINGUES PREREMPLIES DE 0_5ML SANS SYST_ DE SECURITE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [110/1924] Processing: ARAVA 100MG COMP PELLI B_3.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [111/1924] Processing: ARAVA 10MG COMP PELLI B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [112/1924] Processing: ARAVA 20MG COMP PELLI B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [113/1924] Processing: AREDIA 15MG_5ML SOL_INJ_ B_4_4.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [114/1924] Processing: AREDIA 90MG_10ML PDRE_SOL_INJ I_V B_1_1.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [115/1924] Processing: ARIMIDEX 1MG COMP_ENRO_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [116/1924] Processing: arni-calm_B_00.pdf
#   → No text detected → Running OCR
# [117/1924] Processing: arnica-freez_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [118/1924] Processing: AROMASINE 25MG COMP_ ENRO_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [119/1924] Processing: ARTELAC 3_20MG_ML COLLY_ FL__10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [120/1924] Processing: ARTIZ 10MG COMP_ PELLI_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [121/1924] Processing: ARTIZ 10MG_ML  SOL BUV EN GTTES  B _FL 30ML _PIPETTE GRADUEE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [122/1924] Processing: ASCALOL 25G_100G  SOL_ APPLI_ LOCALE FL_125ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [123/1924] Processing: ASIATICOSID 0_02 PDRE FL_ POUDREUR DE 2G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [124/1924] Processing: ASPEC 100MG COMP_ SEC_ B_98.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [125/1924] Processing: ASPEGIC 1G SOL_INJ_ B_06.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [126/1924] Processing: ASPEGIC 500MG_FL_ DE PDRE_ PDRE_ET SOLV_ P_ SOL_ INJ_ IM_IV B_06 FL_ DE PDRE_ _ 06AMP_ DE 5ML DE SOLV_ _EPPI_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [127/1924] Processing: ASPEGIC 500MG_SACH_-DOSE PDRE_ SOL_ BUV_ EN SACH_-DOSE B_20 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [128/1924] Processing: ASPEGIC ADULTE 1G_SACH_-DOSE PDRE_ SOL_ BUV_ EN SACH_-DOSE B_20 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [129/1924] Processing: ASPEGIC ENFANT 250MG_SACH_-DOSE PDRE_ SOL_ BUV_ EN SACH_-DOSE B_20 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [130/1924] Processing: ASPEGIC NOURRISSON 100MG_SACH_-DOSE PDRE_ SOL_ BUV_ SACHET B_20 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [131/1924] Processing: ASPEVASC 100MG COMP_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [132/1924] Processing: ASPIRINE BEKER 500MG COMP_ B_28.pdf
#   → No text detected → Running OCR
# [133/1924] Processing: ASPIRINE UPSA VITAMINE C TAMPONNEE EFFERVESCENTE 330MG_200MG COMP_ EFFERV B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [134/1924] Processing: ASPRO ACCEL 500MG_50MG COMP_ EFFERV_ SEC_  B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [135/1924] Processing: ASPRO ACCEL 500MG_50MG COMP_ PELLI_ SEC_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [136/1924] Processing: ASTHALIN 5MG_ML__ SOL_INHAL_PAR NEBULISEUR FL_15ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [137/1924] Processing: ATABEK 16MG COMP_ SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [138/1924] Processing: ATABEK 8MG COMP_ SEC B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [139/1924] Processing: ATACAND 4MG COMP SEC B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [140/1924] Processing: ATARAX 100MG COMP_PELLI_ SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [141/1924] Processing: ATARAX 25MG COMP_SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [142/1924] Processing: ATARAX 2MG_ML SIROP FL_200ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [143/1924] Processing: atenor-100-mg_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [144/1924] Processing: ATEPADENE 30 mg, gélule_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [145/1924] Processing: ATHYROZOL 5mg COMP_ SEC_ B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [146/1924] Processing: ATOR 10MG COMP_ PELLI_ SEC_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [147/1924] Processing: ATOR 20MG COMP_ PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [148/1924] Processing: ATOR 40MG COMP_ PELLI_ SEC_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [149/1924] Processing: ATOR 80MG COMP_ PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [150/1924] Processing: ATORIN 10MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [151/1924] Processing: ATORIN 20MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [152/1924] Processing: ATORIN 40MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [153/1924] Processing: ATORIN 80MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [154/1924] Processing: ATROPINE - ALCON 0_003 COLLY_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [155/1924] Processing: ATROPINE - ALCON 0_005 COLLY_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [156/1924] Processing: ATROVENT ADUL _ 0_50MG_2ML SOL_INHAL_PAR NEBULISEUR B_10 RECIPIENTS UNIDOSES DE  2ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [157/1924] Processing: ATROVENT ENF_ 0_25MG_2ML SOL_INHAL_PAR NEBULISEUR B_10 RECIPIENTS UNIDOSES DE  2ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [158/1924] Processing: ATUSSINE ADULTES 0_2G_0_2G_100ML SIROP FL_125ML.pdf
#   → No text detected → Running OCR
# [159/1924] Processing: ATUSSINE ENFANTS 0_1G_0_1G_0_4G_100ML SIROP FL_125ML.pdf
#   → No text detected → Running OCR
# [160/1924] Processing: AUGMENTIN 1G_200MG PDRE_SOL_INJ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [161/1924] Processing: AUGMENTIN 2G_200MG PDRE_SOL_INJ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [162/1924] Processing: AUGMENTIN 500MG_50MG PDRE_ P_ SOL_INJ_ B_1.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [163/1924] Processing: AUGMENTIN ADULTE 1G_125MG_SACHET PDRE P_ SUSP_ BUV_ EN SACHET-DOSE B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [164/1924] Processing: AUGMENTIN ADULTES 500MG_62_5MG COMP PELLI B_16 ET B_24.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [165/1924] Processing: AUGMENTIN ENFANT ET AUGMENTIN NOURRISSON  100MG_12_5MG_ML PDRE_ P_ SUSP_ BUV_ B_FL_ DE PDRE_ DE 30ML DE SUSP_ BUV_ ET B_1FL_ DE PDRE_ DE 60ML  DE SUSP_ BUV_ _APRES RECONSTITUTION_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [166/1924] Processing: AUGMENTIN ENFANTS 500MG_62_5MG PDRE_ P_ SUSP_ BUV_ EN SACHET DOSE B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [167/1924] Processing: AVASTIN 25MG_ML _OU 100MG_4ML - 400MG_16ML_ SOL_ A DILUER PERF_ FL_AMP_ DE 4ML ET FL_AMP_DE 16ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [168/1924] Processing: AVELOX 400MG__ COMP_ PELLI_ B_5 - B_7.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [169/1924] Processing: AVLOCARDYL 40MG COMP_SEC_ B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [170/1924] Processing: AVONEX 30µG_0_5ML _OU 6MUI_0_5ML_ SOL INJ IM  B_04 SERINGUES  PRE REMPLIES DE 0_5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [171/1924] Processing: AZANTAC 50MG_2ML SOL_INJ_ B_05.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [172/1924] Processing: AZATHIOPRINE MYLAN 50MG COMP_ PELLI_ SEC_ B_100.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [173/1924] Processing: AZITHROMYCINE BEKER 500MG COMP_ PELLI_ SEC_ B_03.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [174/1924] Processing: AZITHROMYCINE NS 500MG COMP _ PEL_ SEC B_03.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [175/1924] Processing: AZOPT 10MG_ML COLLY_ EN SUSP_ FL__5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [176/1924] Processing: AZYTER 15MG_G__ COLLY_ EN SOL_ EN RECIPIENT UNIDOSE B_06RECIPIENTS UNIDOSES SOUS SACHET.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [177/1924] Processing: B-CORTOSONE 0_5MG_ML _0_05__ SOL_BUV_ GTTES B_30ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [178/1924] Processing: BACRO 10MG COMP_ B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [179/1924] Processing: BACTROBAN 0_02 PDE_ DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [180/1924] Processing: BALSOFUMINE  SIMPLE  SOL_ P_ INHAL_ FL_84ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [181/1924] Processing: BALSOFUMINE MENTHOLEE 0_01 SOL_ P_ INHAL_ FL_84ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [182/1924] Processing: BANEOCIN 250UI_5000UI_G PDRE_ DERM_ FL_10G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [183/1924] Processing: BARACLUDE 0_5MG COMP_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [184/1924] Processing: BARACLUDE 1MG COMP_ B_30.pdf
#   → No text detected → Running OCR
# [185/1924] Processing: BASDENE 25MG COMP_ B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [186/1924] Processing: BECLOJET 250µG_BOUFFEE SUSP_INHAL_BUCCALE FL_200DOSES.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [187/1924] Processing: BECONASE 50µG_ Dose SUSP_NAS_ FL_100DOSES.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [188/1924] Processing: BEDELIX 3G PDRE _ ORAL _ RECT _ B_30 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [189/1924] Processing: BEKERDIS  80MG COMP_ B_30 ET B_90.pdf
#   → No text detected → Running OCR
# [190/1924] Processing: BEKTAL  100MG COMP_PELLI B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [191/1924] Processing: BEKTAL  50MG COMP_ PELLI_ SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [192/1924] Processing: BEPANTHENE 100MG COMP_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [193/1924] Processing: BEPANTHENE 250MG_ML _500MG_2ML_ SOL_ INJ_ IM B_06AMP_ DE 2ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [194/1924] Processing: BETACROVIS 0_5MG_ML _0_05__ SOL_BUV_ GTTES FL_40ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [195/1924] Processing: BETACYL 0_05G__3G_ PDE_ DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [196/1924] Processing: BETAFERON 250µG_ML _8MUI_ML_ DE SOL_ RECONSTITUEE PDRE_ ET SOLV_ P_ SOL_ INJ_ SC B_15PRESENTATIONS UNITAIRES CONTENANT CHACUNE 1FLACON DE PDRE__1SERING_PREREMPLIE DE 1_2ML DE SOLV__2TAMPONS IMBIBES DALCOOL_1ADAPTEUR POUR FLACON AVEC AIGUILLE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [197/1924] Processing: BETAIODINE 0_05 SOL_ APPL_ LOCALE  FL__70ML EN SPRAY.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [198/1924] Processing: BETAMETHASONE EG 2 mg, comprimé dispersible sécable_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [199/1924] Processing: BETAMETHASONE PHYSIOPHARM 0_5MG_ML _0_05__ SOL_ BUV_ GTTES_ B_1FL DE 30ML_ PIPETTE GRADUEE EN ML  _2ml_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [200/1924] Processing: BETASERC 24MG COMP_ B_60.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [201/1924] Processing: BETASONE 0_0005 PDE_DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [202/1924] Processing: BETASONE 0_001 PDE_DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [203/1924] Processing: BETOPTIC 0_005 COLLY_ FL_3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [204/1924] Processing: BI-OROGYL 1_5MUI_250MG COMP_ PELLI_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [205/1924] Processing: BIAFINE 0_670G_100G EMULS_POUR APPLIC_ CUTANEE T_93G _100ML_  ET T_186G_200ML_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [206/1924] Processing: BILAXTEN 20MG COMP_ SEC_ B_10 ET B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [207/1924] Processing: BINOZYT 250MG GLES_ B_06.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [208/1924] Processing: BINOZYT 500MG COMP_ ENRO_ B_03.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [209/1924] Processing: BIOCALYPTOL A LA PHOLCODINE 131MG_19_75MG_100ML SIROP FL_200ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [210/1924] Processing: BIOCLAV 100MG_12_5MG_ML PDRE_ P_ SUSP_ BUV_ ENFANT  B_1FL_ DE 60ML DE SUSP_ BUV_ APRES RECONST_ _ 1SERING_ GRADUEE EN KG.pdf
#   → No text detected → Running OCR
# [211/1924] Processing: BIOCLAV 500MG_62_5MG COMP_ PELLI_ B_16.pdf
#   → No text detected → Running OCR
# [212/1924] Processing: BIOCLAV 8_1 1G_125MG_SACHET PDRE P_ SUSP_ BUV_ EN SACHET-DOSE   B_14.pdf
#   → No text detected → Running OCR
# [213/1924] Processing: BIOCLAV 8_1 1G_125MG_SACHET PDRE P_ SUSP_ BUV_ EN SACHET-DOSE  B_12.pdf
#   → No text detected → Running OCR
# [214/1924] Processing: BIOCLAV 8_1 1G_125MG_SACHET PDRE P_ SUSP_ BUV_ EN SACHET-DOSE B_08.pdf
#   → No text detected → Running OCR
# [215/1924] Processing: BIONOLYTE G5 0_2G_0_4G_5G_100ML SOL_ PERF_IV FL__500ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [216/1924] Processing: BIOPAMOX 1G_FL_ DE PDRE_ PDRE_ P_ SOL_ INJ_ IM B_01 FL_ DE PDRE_ _ 01 AMP_ DE 5ML DE SOLV_ _ALCOOL BENZYLIQUE_EPPI_ ET B_50 FL_ DE PDRE_.pdf
#   → No text detected → Running OCR
# [217/1924] Processing: BIOPAMOX 1G_SACHET GRANULés POUR SUSPENSION BUVABLE B_08.pdf
#   → No text detected → Running OCR
# [218/1924] Processing: BIOPAMOX 250MG_5ML PDRE_ P_ SUSP_ BUV_ FL__60ML ET FL__100ML _DE SUSP_ BUV_ APRES RECONSTITUTION_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [219/1924] Processing: BIOPAMOX 500MG GLES_ B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [220/1924] Processing: BIOPAMOX 500MG_5ML PDRE_ P_ SUSP_ BUV_ B_1FL_ DE 60ML DE SUSP_ BUV_ APRES RECONST_ _  BOUCHON DOSEUR GRADUE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [221/1924] Processing: BIOVEX 500MG_ 200MG_ 25MG GRANULES POUR SOL BUV EN SACHET ADULTE B_08 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [222/1924] Processing: BIPRETERAX ARGININE 5MG_1_25MG COMP_ PELLI_ PILULIER_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [223/1924] Processing: BIRODOGYL 1_5MUI_250MG COMP_ PELLI_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [224/1924] Processing: BISOPROLOL BEKER 10MG  COMP PELL SEC  B_30 ET B_90.pdf
#   → No text detected → Running OCR
# [225/1924] Processing: BISOPROLOL BEKER 5MG  COMP PELL  B_30 ET B_90.pdf
#   → No text detected → Running OCR
# [226/1924] Processing: BLEOMYCINE 15MG PDRE_SOL_INJ_ B_01.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [227/1924] Processing: BONASOL 70 mg, solution buvable_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [228/1924] Processing: BONEFOS 800MG COMP_ PELLI_ B_100.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [229/1924] Processing: BOROSTYROL 0_90G_0_60G_1_34G_100G CREME T_50G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [230/1924] Processing: BOSENTAS 125MG COMP_ PELLI_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [231/1924] Processing: BOSENTAS 62_5MG COMP_ PELLI_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [232/1924] Processing: BRICANYL  5MG_2ML SOL_ P_ INHAL_ BUCC_ PAR NEBULISEUR EN RECIPIENT UNIDOSE DE 2ML B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [233/1924] Processing: BRICANYL 0_5MG_ML SOL_INJ_S_C B_8.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [234/1924] Processing: BRICANYL LP 5MG COMP_ LP PILULIER_60.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [235/1924] Processing: BRICANYL TURBUHALER 0_5MG_ DOSE PDRE_ P_ INHAL_ BUCC_ Fl__100DOSES.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [236/1924] Processing: BRILIQUE 90MG COMP_ PELLI_ B_60 ET B_100.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [237/1924] Processing: BROMAZEPAM 6MG COMP_ QUADRI SEC_ B_30.pdf
#   → No text detected → Running OCR
# [238/1924] Processing: BRONCHOCALM ADULTES 0_2_ SIROP  FL_150ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [239/1924] Processing: BRONCHOCALM ENFANTS 0_1_ SIROP  FL_125ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [240/1924] Processing: BROXOL 0_003 SIROP  FL__100ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [241/1924] Processing: BUFEN 20MG_ML _100MG_5ML_ SUSP_ BUV_ FL__125ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [242/1924] Processing: BUPIVACAINE AGUETTANT 0_0025 SOL _INJ_ B_10FL_ DE 20ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [243/1924] Processing: BUPIVACAINE MYLAN 0_005 SOL_ INJ_ B_10FL_ DE 20ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [244/1924] Processing: BUPIVACAINE MYLAN 5MG_ML _20MG_4ML_ SOL_ INJ_ IRACH_ B_20AMP_ DE 4ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [245/1924] Processing: BUPRINAL 0_3MG_ML SOL_ INJ_ IM_IV_SC_VOIE MEDULLAIRE B_05 AMP_ DE 2ML CONTENANT 1ML DE SOLUTION.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [246/1924] Processing: BUSILVEX 6MG_ML _60MG_10ML_ SOL_ A DILUER P_ PERF_ IV B_08FL_ DE 10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [247/1924] Processing: BUTAFEN 200MG GLES_ A MICROGRLES_  B_20.pdf
#   → No text detected → Running OCR
# [248/1924] Processing: BUTAFEN 600MG COMP_ PELLI_ B_30.pdf
#   → No text detected → Running OCR
# [249/1924] Processing: BUTAFEN LP 400MG MICROGRANULES LP EN GLES_ B_20.pdf
#   → No text detected → Running OCR
# [250/1924] Processing: CALCIDOSE 500MG_SACHET DOSE _1250MG_SACHET DOSE DE CARBONATE DE CALCIUM _ PDRE_ SUSP_ BUV_EN SACHET DOSE B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [251/1924] Processing: CALCIDOSE VITAMINE D 400UI_500MG_SACHET PDRE_ ORALE EN SACH_-DOSE B_30 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [252/1924] Processing: CALCIUM HYSA 500MG DE CALCIUM _1250MG DE CALCIUM CARBONATE_ PDRE_ P_ SUSP_ BUV_ EN SACH_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [253/1924] Processing: CALCIUM SANDOZ 3_40G_0_150G_SACHET OU 500MG EN CALCIUM ELEMENT PDRE  EN SACH_ POUR SOL_BUV_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [254/1924] Processing: CALCIUM SANDOZ 500MG__ _ SEL 2_94G _ 0_3 G_ COMP_EFFERV_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [255/1924] Processing: CALMIG 50MG COMP_ B_2  ET B_6.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [256/1924] Processing: CALPEROS 500MG COMP A SUCER SEC B_60.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [257/1924] Processing: CAMPTO 20MG_ML  _OU 40MG_2ML  ET 100MG_5ML_ SOL_ A  DILUER  PERF_ IV STRICTE B_1FL_ 2ML _40MG_2ML_ ET  B_1FL__5ML _100MG_5ML_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [258/1924] Processing: CANCIDAS 50MG_FL_ DE PDRE_ PDRE_ P_ SOL_ A DILUER P_ PERF_ IV B_1FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [259/1924] Processing: CANCIDAS 70MG_FL_ DE PDRE_ PDRE_ P_ SOL_ A DILUER P_ PERF_ IV B_1FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [260/1924] Processing: canderax-4mg-8mg-16mg_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [261/1924] Processing: canderax_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [262/1924] Processing: CANESTEN 1G_ CREME_DERM_ T_30G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [263/1924] Processing: CAPTOPRIL LS 25MG COMP_ SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [264/1924] Processing: CAPTOPRIL LS 50MG COMP_ SEC_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [265/1924] Processing: CARBIMAZOLE GS 5MG COMP_ SEC_ B_50.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [266/1924] Processing: CARBIMOL 200MG  COMP PELL  B_30.pdf
#   → No text detected → Running OCR
# [267/1924] Processing: CARBIMOL LP 400MG COMP_ PELLI_ SEC_ LP B_30.pdf
#   → No text detected → Running OCR
# [268/1924] Processing: CARBODAL SANS SUCRE 0_05 SOL_ ORA_ FL__125ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [269/1924] Processing: CARBOPLATINE EBEWE 10MG_ML _OU 50MG_5ML -  150MG_15ML - 450MG_45ML_ SOL_ PERF_ FL_5ML -  FL_15ML - FL_45ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [270/1924] Processing: CARBOPLATINE MYLAN 10MG_ML  _OU 50MG_5_ML -  150MG_15ML -  450MG_45ML_ SOL_ INJ_ PERF_ B_1FL__5ML - B_1FL__15ML  ET  B_1FL__45ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [271/1924] Processing: CARDAXEL BGL 16MG COMP_ SEC_ B_30.pdf
#   → No text detected → Running OCR
# [272/1924] Processing: CARDAXEL BGL 8MG COMP_ SEC_ B_30.pdf
#   → No text detected → Running OCR
# [273/1924] Processing: CARDAXEL PLUS  16MG _ 12_5MG COMP_ B_30.pdf
#   → No text detected → Running OCR
# [274/1924] Processing: CARDAXEL PLUS 8MG_12_5MG COMP B_30.pdf
#   → No text detected → Running OCR
# [275/1924] Processing: CARDULAR 2MG COMP_ SEC_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [276/1924] Processing: CARTEOL 0_01 COLLY_ FL_3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [277/1924] Processing: CARTEOL 0_02 COLLY_ FL_3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [278/1924] Processing: CARTEOL LP 0_01 COLLY_ EN SOL_ LP  FL__3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [279/1924] Processing: CARTEOL LP 0_02 COLLY_ EN SOL_ LP  FL__3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [280/1924] Processing: CASODEX 50MG COMP_ ENRO_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [281/1924] Processing: CATAFLAM 50MG COMP_ ENRO_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [282/1924] Processing: CATAPRESSAN 0_15MG COMP_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [283/1924] Processing: CATAPRESSAN 0_15MG_ML SOL_INJ_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [284/1924] Processing: CEBEMYXINE 3 400UI_10 000UI COLLY_ EN SOL_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [285/1924] Processing: CEBEMYXINE 340 000UI_1 000 000 UI _100G PDE OPHT T_5G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [286/1924] Processing: CEBESINE 0_4_ COLLY_ EN SOL_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [287/1924] Processing: CEDROX 1G COMP_ B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [288/1924] Processing: CEFAXONE 100MG_ML _1000MG_10ML_ PDRE_ET SOLV_ SOL_ IV      B_1FL_ PDRE_ _ 1AMP_ DE SOLV_ DE 10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [289/1924] Processing: CEFAZOLIN 1G_FL_ DE PDRE_ PDRE_ ET SOLV_SOL_INJ_ IM B_1FL_ PDRE__1AMP_ DE 3ML DE SOLV_ _0_5_ LIDOCAINE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [290/1924] Processing: CEFAZOLINE   1G PDRE_SOL_INJ IM_IV B_1_1 et B_50FL_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [291/1924] Processing: cefimax-nourissons-enfants_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [292/1924] Processing: cefixim-200-mg_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [293/1924] Processing: CEFODEX 1GR_FLACON  POUDRE ET SOLVANT POUR PREPARATION INJECTABLE IM ET IV  B_01 FLACON DE POUDRE _ 01 FLACON DE SOLVANT.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [294/1924] Processing: CEFTAZIM 1G_FL_ DE PDRE_ _ADULTE_ PDRE_ P_ SOL_ INJ_ IM_IV B_1FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [295/1924] Processing: CEFTAZIM 500MG_FL_ DE PDRE_ _ENFANT ET NOURRISSON_ PDRE_ P_ SOL_ INJ_ IM_IV B_1FL_ DE PDRE_ P_ ENFANT ET NOURRISSON.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [296/1924] Processing: CELEBREX 100MG GLES_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [297/1924] Processing: CELEBREX 200MG GLES_ B_10 - B_15 - B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [298/1924] Processing: celecox-100-mg-200-mg_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [299/1924] Processing: CELECOXIB BEKER 100MG GLES B_20.pdf
#   → No text detected → Running OCR
# [300/1924] Processing: CELECOXIB BEKER 200MG GLES_ B_10.pdf
#   → No text detected → Running OCR
# [301/1924] Processing: CELESTENE 0_5MG_ML _0_05__ SOL_BUV_ GTTES FL_30 ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [302/1924] Processing: CELESTENE 2MG COMP_ DISPERS_ SEC_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [303/1924] Processing: CELESTENE CHRONODOSE 2_7MG_3MG_AMP_ SUSP_INJ_ B_1AMP_ _1SERINGUE _ 2AIGUILLES.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [304/1924] Processing: CEPHALEX 500MG GLES_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [305/1924] Processing: CERAZETTE 0_075MG COMP_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [306/1924] Processing: CEREZYME 400 UNITES DIMIGLUCERASE _ FL_ DE PDRE_ PDRE_ A DILUER SOL_ PERF_ IV B_01FL_  DE PDRE_ 400UI.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [307/1924] Processing: CERUBIDINE 20MG PDRE_SOL_INJ_ B_10FL_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [308/1924] Processing: CERULYSE 5G_100G SOL_ AURIC_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [309/1924] Processing: Cetalgine.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [310/1924] Processing: CETIRIZINE EG 10 mg, comprimé pelliculé sécable_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [311/1924] Processing: CETIRIZINE MYLAN 10MG COMP_ PELLI_SEC_ B_15.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [312/1924] Processing: CETORNAN 5G_SACHET-DOSE PDRE_ P_ SOL_ BUV_ OU GASTRO-ENTERALE B_10 SACHETS.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [313/1924] Processing: CETROTIDE 0_25MG_FL_ DE PDRE PDRE ET SOLV_ SOL_ INJ_ SC B_01FL_ PDRE _ 01 SERING_ PRE REMPL_ SOLV_ _EPPI_ _ 01 AIGUILLE 20G _ 01 AIGUILLE HYPODERMIQUE 27G _ 02 TAMPONS IMBIBES DALCOOL.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [314/1924] Processing: CHARBON ACTIVE IVAL 300MG COMP_  B_40.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [315/1924] Processing: CHARBON DE BELLOC 125 mg, capsule molle_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [316/1924] Processing: CHIBRO-CADRON 100MG_350000UI_100ML COLLY_ FL_5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [317/1924] Processing: CHIBROXINE 0_3_ _OU 3MG_ML_ COLLY_ FL_5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [318/1924] Processing: CHLORURE DE POTASSIUM AGUETTANT 0_1 SOL_INJ_ B_50AMP_ DE  20ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [319/1924] Processing: CHLORURE DE SODIUM BIEFFE 0_009 SOL INJ_  POCHE DE 500ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [320/1924] Processing: CIBACALCINE 0_5MG PDRE_SOL_INJ B_5_5.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [321/1924] Processing: Cicatrine-5mg-ovule_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [322/1924] Processing: cicatrine_B_00.pdf
#   → No text detected → Running OCR
# [323/1924] Processing: CICOLINA 100MG_ML__ _OU 10G_100ML_ SOL_ BUV_ FL__60ML _ PIPETTE DOSEUSE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [324/1924] Processing: CILOXAN 0_003 COLLY_ FL__5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [325/1924] Processing: CILOXAN 0_003 PDE_OPHT_ T_3_5G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [326/1924] Processing: CIPRO 500 500MG COMP_ PELLI_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [327/1924] Processing: CIPRO 750 750MG COMP_ PELLI_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [328/1924] Processing: ciprodar_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [329/1924] Processing: CIPROFLOXACINE BEKER  500MG COMP_ PELLI_ SEC_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [330/1924] Processing: CIPROFLOXACINE BEKER  750MG COMP_ PELLI_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [331/1924] Processing: CIPROLON 250MG COMP_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [332/1924] Processing: CIPROLON 500MG COMP_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [333/1924] Processing: CIPTADINE 4MG COMP_ SEC_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [334/1924] Processing: CISPLATIN EBEWE 0_5MG_ML _25MG_50ML_ - _50MG_100ML_ CONC_SOL_INJ_ PERF_ IV B_1FL DE 50 ML  - B_1FL_ DE 100ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [335/1924] Processing: CISPLATINE MYLAN 1MG_ML _OU 10MG_10ML - 25MG_25ML - 50MG_50ML_ SOL_ INJ_ A DILUER PERF_IV FL__10ML - FL__25ML - FL__50ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [336/1924] Processing: CITAL 50MG COMP B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [337/1924] Processing: CITICOLINE ISO 100MG_ML__ SOL_ BUV_ GTTES_ FL__50ML AVEC PIPETTE GRADUEE.pdf
#   → No text detected → Running OCR
# [338/1924] Processing: CLAMOXYL 1G COMP_ DISPERS_ B_06 - B_12 ET B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [339/1924] Processing: CLAMOXYL 250MG_5ML PDRE_ P_ SUSP_BUV_ F_60ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [340/1924] Processing: CLAMOXYL 500MG_5ML PDRE_ SUSP_ BUV_  FL_60ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [341/1924] Processing: CLARADINE 1MG_ML SOL_ BUV_ FL__60ML.pdf
#   → No text detected → Running OCR
# [342/1924] Processing: CLARDINE 1MG_ML SOL_ BUV_ FL__60ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [343/1924] Processing: CLARITYNE 1MG_ML SIROP FL__60ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [344/1924] Processing: CLENIL 250µG_BOUFFEE AERO_ FL_200DOSES.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [345/1924] Processing: CLIMASTON 1MG_10MG COMP PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [346/1924] Processing: CLIMASTON 1MG_5MG COMP PELLI B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [347/1924] Processing: CLIMASTON 2MG_10MG COMP_ PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [348/1924] Processing: CLIMENE 2MG_1MG COMP_ENRO_ B_21.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [349/1924] Processing: CLOFENAL 100MG SUPPO_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [350/1924] Processing: CLOFENAL 25MG_ML _75MG_3ML_ SOL_INJ_IM  B_02AMP_ DE 3ML ET B_50AMP_ DE 3ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [351/1924] Processing: CLOGEL 0_01 GEL DERM_ T_30G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [352/1924] Processing: CLOMID 50MG COMP_ B_5.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [353/1924] Processing: CLOMYCINE 0_01 PDE_OPHT_ T_5G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [354/1924] Processing: CLOMYCINE 0_03 PDE_DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [355/1924] Processing: CLONA 2MG COMP_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [356/1924] Processing: CLONA 2_5MG_ML SOL_ BUV_ GTTES_ FL_ COMPTE GTTES_ DE 20ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [357/1924] Processing: CLONAPRIME 10MG COMP_ PELLI_ B_60.pdf
#   → No text detected → Running OCR
# [358/1924] Processing: CLONAPRIME 25MG COMP_ PELLI_ B_30.pdf
#   → No text detected → Running OCR
# [359/1924] Processing: CLONAPRIME 75MG COMP_ PELLI_ SEC_ B_20.pdf
#   → No text detected → Running OCR
# [360/1924] Processing: CLOPRAMID 0_001 SOL_BUV FL_125ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [361/1924] Processing: CLORAXENE 5MG GLES_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [362/1924] Processing: CLOTASOL 0_05_ CREME DERM_ T_45G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [363/1924] Processing: CLOTASOL 0_05_ GEL P_ APPLI_ CAPILLAIRE T_45G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [364/1924] Processing: CLOVIR 200MG COMP_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [365/1924] Processing: CLOVIRAX 0_05 CREME DERM_ T_2G ET T_10G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [366/1924] Processing: clovirax-comprime-200-mg_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# ...
#   → Selectable text detected → Copied to selectable_pdfs
# [1799/1924] Processing: VALASTAN 160MG COMP_ PELLI_ B_28 - B_98.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1800/1924] Processing: VALASTAN 80MG COMP_ PELLI_ B_28 - B_98.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1801/1924] Processing: VALPROATE DE SODIUM BGL 200MG_ML SOL_ BUV_ B_1FL_ DE 40ML _ 1SERING_ GRADUEE.pdf
#   → No text detected → Running OCR
# [1802/1924] Processing: VALPROCIDE GS CHRONO 500MG__ _333MG DACIDE VALPROIQUE SEL SODIIQUE _ 147MG DACIDE VALPROIQUE_ COMP_ SEC_ LP B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1803/1924] Processing: VANCOMYCINE MYLAN 500MG_FL DE PDRE___ PDRE_ SOL_ PERF_  B_1FL_DE PDRE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1804/1924] Processing: VASTAREL 35MG COMP_ PELLI_ LM B_60.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1805/1924] Processing: vastor-20mg-comprime-pellicule_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1806/1924] Processing: VAVO 0_02 CREME DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1807/1924] Processing: VAVO SHAMPOO 0_02 SHAMPOING FL__100ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1808/1924] Processing: VECTIBIX 20MG_ML _100MG_5ML_ _400MG_20ML_ SOL_ A DILUER P_ PERF_ IV B_01 FL_ DE 5ML _ B_01 FL_ DE 20ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1809/1924] Processing: VELCADE 3_5MG_FL_ DE PDRE_ _OU 1MG_ML DE SOL_ RECONSTITUEE_ PDRE_ SOL_ INJ_ IV B_1FL_ DE PDRE_ DE CONTENANCE 10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1810/1924] Processing: VELITEN 200MG _ 50MG _ 200MG COMP_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1811/1924] Processing: VENOSMIL 200MG GLES B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1812/1924] Processing: VENTAVIS 10 UG_ML SOLUTION POUR INHALATION PAR NEBULISEUR B_30 AMP DE 2ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1813/1924] Processing: VENTOLINE 0_5MG_ML SOL_INJ_S_C B_6AMP.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1814/1924] Processing: VENTOLINE 100µG_DOSE AERO_ FL_200DOSES.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1815/1924] Processing: VENTOLINE 2MG COMP_ B_40.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1816/1924] Processing: VENTOLINE 5MG_ML SOL_NEB_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1817/1924] Processing: VESICARE 10MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1818/1924] Processing: VESICARE 5MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1819/1924] Processing: VEXOL 0_01 COLLY_ FL__5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1820/1924] Processing: VFEND 200MG COMP_ PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1821/1924] Processing: VFEND 200MG_FL_ DE PDRE_ _OU 10MG_ML DE SOL_ RECONSTITUEE_ PDRE_ SOL PERF_IV B_1FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1822/1924] Processing: VFEND 50MG COMP_ PELLI_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1823/1924] Processing: VIABEK 100MG COMP_ PELLI_ B_04.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1824/1924] Processing: VIABEK 50MG  COMP_ PELLI_ SEC B_02.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1825/1924] Processing: VIACTAL 50MG  COMP_ B_02  -  B_08.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1826/1924] Processing: VIADIS 50MG  COMP_ PELLI_ B_02 ET B_04.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1827/1924] Processing: VIAGRA 50MG  COMP_ PELLI_ B_02.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1828/1924] Processing: VIBRAMYCINE 100MG COMP_ SEC_ B_05.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1829/1924] Processing: VICTRELIS 200 MG GELULE B_336.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1830/1924] Processing: vircet-50mg-100mg-200mg-gelule_B_06.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1831/1924] Processing: VIRGAN 0_15__ GEL_OPHT T_5G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1832/1924] Processing: VISANNE 2MG  COMP  B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1833/1924] Processing: VISCERALENE 20MG SUPPO B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1834/1924] Processing: VISUDYNE 15MG PDRE_SOL_INJ_ IV B_01FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1835/1924] Processing: VITABACT 0_0005 COLLY_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1836/1924] Processing: vital-mag-150mg-375mg-comprime_B_04.pdf
#   → No text detected → Running OCR
# [1837/1924] Processing: VITALIS 20MG COMP_ PELLI_ SEC_ B_02.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1838/1924] Processing: VITAMINE  C 500MG COMP_EFFER_ T_16.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1839/1924] Processing: VITAMINE A FAURE 150 000UI COLLY_ FL_10ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1840/1924] Processing: VITAMINE B12 RAZES  500 µG_ML _OU 1000µG_2ML_ SOL_INJ_ ET BUV B_5AMP.pdf
#   → No text detected → Running OCR
# [1841/1924] Processing: VITAMINE C UPSA 500MG COMP_ A CROQUER B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1842/1924] Processing: VITAMINE C UPSA EFFERVESCENTE 1G COMP_ EFFERV_  B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1843/1924] Processing: VOGALON-25-5-mg.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1844/1924] Processing: VOGALYS-75-mg.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1845/1924] Processing: VOLTARENE 100MG SUPPO_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1846/1924] Processing: VOLTARENE DOLO 12_5MG  COMP ENRO  B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1847/1924] Processing: VOLTARENE EMULGEL 0_01 GEL DERM_ T_50G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1848/1924] Processing: voltum-25mg-100mg-suppositoire_B04.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1849/1924] Processing: voltum-25mg-50mg-comprime_B_04.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1850/1924] Processing: voltum-gel-1-et-2-emulsion-gel_B_04.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1851/1924] Processing: voltum-lp-100mg-gelule_B_06.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1852/1924] Processing: VOLUVEN 6_ 6G _ 0_9G _ 100ML SOL_ PERF_ IV POCHE_500ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1853/1924] Processing: VOTREX 50MG COMP_ GASTRORESIST_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1854/1924] Processing: VOTREX RETARD 100MG COMP_ PELLI_ LP B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1855/1924] Processing: VPRIV 400 U DE VELAGLUCERASE ALFA _ FL_ DE PDRE_ _100U DE VELAGLUCERASE _ML APRES RECONSTITUTION_ PDRE_ P_ SOL_ P_ PERF_ IV B_01 FL_ DE PDRE_.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1856/1924] Processing: WARTEC 0_0015 CREME T_5G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1857/1924] Processing: WINEX 200MG GLES_ B_08.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1858/1924] Processing: WINEX 400MG GLES_ B_06.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1859/1924] Processing: XALACOM 50μG_5MG_ML _0_005__0_5__ COLLYRE FL__2_5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1860/1924] Processing: XALDOL 325MG _ 37_5MG GELULE B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1861/1924] Processing: XAMADOL 325MG _ 37_5MG COMP_ PELLI_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1862/1924] Processing: XARELTO 10MG COMP_ PELLI_ B_05 - B_10 - B_30 - B_100.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1863/1924] Processing: XARELTO 15MG COMP_ PELLI_ B_14 - B_42 - B_100.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1864/1924] Processing: XARELTO 20MG COMP_ PELLI_ B_28 - B_100.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1865/1924] Processing: XATRAL LP 5MG COMP_ PELLI_ LP B_56.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1866/1924] Processing: XAVEL 1_ _OU 10MG_ML_ SOL_ BUV_ GTTES_ B_1FL_ COMPT_ GTTES DE 20ML.pdf
#   → No text detected → Running OCR
# [1867/1924] Processing: XEFURYL 200MG GLES_ B_28.pdf
#   → No text detected → Running OCR
# [1868/1924] Processing: XELODA 500MG COMP_ PELLI_ B_120.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1869/1924] Processing: XENETIX I_300MG_ML SOL_ INJ_ INTRA-VASC_ ET INTRA-CAVITAIRE FL__50ML ET FL__100ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1870/1924] Processing: XENETIX I_350MG_ML SOL_ INJ_ INTRA-VASC_ ET INTRA-CAVITAIRE FL__50ML ET FL__100ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1871/1924] Processing: XGEVA 70MG_ML _120MG_1_7ML_ SOL_ INJ_ SC B_01 FL_ USAGE UNIQUE 1_7ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1872/1924] Processing: XOLAIR 150MG_FL POUDRE ET SOLVANT POUR PREPARATION INJECTABLE S_C B_01 FLACON DE  POUDRE DE 5ML ET SOLV 2ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1873/1924] Processing: XOLAMOL 20MG_5MG_ML COLLY_EN SOL_ FL__5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1874/1924] Processing: XYCARE 5 MG COMP_ PELLI_  B_28.pdf
#   → No text detected → Running OCR
# [1875/1924] Processing: XYCARE 5 MG COMP_ PELLI_ B_14.pdf
#   → No text detected → Running OCR
# [1876/1924] Processing: XYDOL 200MG COMP_ PELLI_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1877/1924] Processing: XYDOL 400MG COMP_ PELLI_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1878/1924] Processing: XYDOL 600MG COMP_ PELLI_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1879/1924] Processing: XYDOL GYN 100MG COMP_ PELLI_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1880/1924] Processing: XYDOL RHUME 200MG_30MG COMP_ PELLI_ B_20.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1881/1924] Processing: XYLOCAINE 0_01 SOL_INJ_ FL_20ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1882/1924] Processing: XYLOCAINE VISQUEUSE 0_02 GEL ORAL T_100G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1883/1924] Processing: ZADITEN 1MG_5ML SIROP SANS ALCOOL B_1FL_ DE 150ML _ UNE CUILLERE_ MESURE DE 5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1884/1924] Processing: ZALERG 0_25MG_ML COLLYRE EN SOL_ SANS CONSERVATEUR B_1FL_ DE 5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1885/1924] Processing: ZANIDIP 10MG COMP PELL SEC B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1886/1924] Processing: ZANITRA 5MG COMP_ B_60.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1887/1924] Processing: ZANITRA PLUS 49_297MG_0_50MG  GLES_ B_30.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1888/1924] Processing: ZECLAR 125MG_5ML GRLES_ SUSP_ BUV_ FL__100ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1889/1924] Processing: ZECLAR 250MG COMP_ PELLI_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1890/1924] Processing: ZECLAR 250MG_5ML GRLES_ SUSP_ BUV_ FL__60ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1891/1924] Processing: ZECLAR 500MG COMP_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1892/1924] Processing: zeclar_500mg_comp._b_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1893/1924] Processing: ZEEFRA GE 500MG GLES_ B_12.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1894/1924] Processing: ZETA 0_02 CREME DERM_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1895/1924] Processing: ZETA 0_02 PDE_ T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1896/1924] Processing: ZETA-CORT 0_1__2_ CREME T_15G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1897/1924] Processing: ZETIREC 10MG_ML SOL_ BUV_ GTTES_ B_01FL COMPTE GTTES DE 15ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1898/1924] Processing: ZIMOR 20MG GLES_ A MICROG_ GASTRORESIST_ B_14 ET B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1899/1924] Processing: ZINACEF 750MG__ PDRE _SOL_INJ_ IM_I_V B_5FL.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1900/1924] Processing: ZINNAT 125MG COMP_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1901/1924] Processing: ZINNAT 125MG_5ML SUSP_ BUV_ FL_70ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1902/1924] Processing: ZINNAT 250MG COMP_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1903/1924] Processing: ZINOXIMOR 250MG COMP_ PELLI_ B_10.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1904/1924] Processing: ZINOXIMOR 500MG COMP_ PELLI_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1905/1924] Processing: ZITHROMAX 500MG COMP_ PELLI_ SEC_  B_03.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1906/1924] Processing: ZODID 50MG GLES_ B_30.pdf
#   → No text detected → Running OCR
# [1907/1924] Processing: ZOLADEX 10_8MG IMPLANT S_C_ EN SERINGUE PRE REMPLIE B_01 SERINGUE AVEC SYSTÈME DE SECURITE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1908/1924] Processing: ZOLADEX 3_6MG IMPLANT S_C_ EN SERINGUE PRE REMPLIE B_01 SERINGUE AVEC SYSTÈME DE SECURITE.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1909/1924] Processing: ZOLOFT 50MG  GLES_ B_14.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1910/1924] Processing: ZOMAX 500MG COMP_ B_03.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1911/1924] Processing: ZOMETA 0_8MG_ML _4MG_5ML_ SOL_ A DILUER PERF_IV B_01FL_ DE 5ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1912/1924] Processing: ZOPHREN 2MG_ML _OU 4MG_2ML ET 8MG_4ML_ SOL _INJ_ B_5AMP  2ML ET 4ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1913/1924] Processing: zostine-20mg-40mg-comprime-pellicule_B_07.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1914/1924] Processing: zotrix-40mg-sirop_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1915/1924] Processing: ZOTRIX_250 mg_comprimé pelliculé_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1916/1924] Processing: ZOVIRAX 0_03 PDE OPHT T_4_5 G.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1917/1924] Processing: ZOVIRAX 250MG  PDRE_SOL_INJ_ B_1FL.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1918/1924] Processing: ZOXAN LP 4MG COMP_ LP B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1919/1924] Processing: ZOXAN LP 8MG COMP_ LP B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1920/1924] Processing: ZYLORIC 100MG COMP_ B_28.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1921/1924] Processing: zynax-125mg-5ml-sirop_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1922/1924] Processing: zynax-250mg-500mg-comprime-pellicule_B_00.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1923/1924] Processing: ZYRTEC 10MG_ML SOL BUV_GTTES B_01FL COMPTE GTTES DE 15ML.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# [1924/1924] Processing: ZYTIGA 250MG COMP_ B_1FL_ DE 120.pdf
#   → Selectable text detected → Copied to selectable_pdfs
# ✅ Classification complete.

# %%
## As i noticed that there are some files missing that were not processed, i want to get their names to see where is the issue

raw_dir = r"\Dataa\unzipped_pdfs"
ocr_dir = r"\Dataa\ocr_pdfs"
selectable_dir = r"\Dataa\selectable_pdfs"

# Get sets of all filenames
all_files = set(f for f in os.listdir(raw_dir) if f.endswith(".pdf"))
ocr_files = set(os.listdir(ocr_dir))
selectable_files = set(os.listdir(selectable_dir))

# Files that made it to either folder
processed_files = ocr_files.union(selectable_files)

# Find the ones that were not processed
missing_files = sorted(list(all_files - processed_files))

print(f"Total missing files: {len(missing_files)}\n")
print("Missing file names:")
for name in missing_files:
    print(name)
# Out:
# ❌ Total missing files: 13
#
# Missing file names:
# AMITRAL 100MG COMP_ DISPERS_  B_30.pdf
# AMITRAL 25MG COMP_ DISPERS_ B_30.pdf
# AMITRAL 5MG COMP_ DISPERS_  B_30.pdf
# AMODEX-Gé 250MG_5ML PDRE_ P_ SUSP_ BUV_ FL_60ML.pdf
# COLOSTOP 200MG COMP B_30.pdf
# GLUCOPHAGE  1000MG COMP_ PELLI_ SEC_ B_30.pdf
# KYNCEPT 10 MG COMP ORODISPERSIBLE B_30.pdf
# KYNCEPT 5 MG COMP ORODISPERSIBLE B_30.pdf
# LEVOCARB 250MG_25MG__ COMP_ SEC_ B_100.pdf
# RISPAL 1MG COMP_ PELLI_ SEC_ B_60.pdf
# RISPAL 2MG COMP_ PELLI_ SEC_ B_60.pdf
# RISPAL 4MG COMP_ PELLI_ SEC_ B_30.pdf
# VITAMINE B12 RAZES  500 µG_ML _OU 1000µG_2ML_ SOL_INJ_ ET BUV B_5AMP.pdf

# %%
## Since OCRmyPDF failed on the missing files another solution is implemented in this script:

"""
This code applies manual OCR to a list of failed PDFs by converting each page to an image,
running Tesseract OCR, and saving the output as a searchable PDF with the original filename.
"""

from pdf2image import convert_from_path
from PyPDF2 import PdfMerger
import pytesseract
from PIL import Image
import tempfile


missing_dir = r"\Dataa\unzipped_pdfs"  
output_dir = r"\Dataa\ocr_pdfs"
os.makedirs(output_dir, exist_ok=True)


#Processing each missing file 
for filename in missing_files:
    input_path = os.path.join(missing_dir, filename)
    output_path = os.path.join(output_dir, filename)

    print(f"OCR-ing: {filename}")

    try:
        # Converting PDF pages to images
        images = convert_from_path(input_path, dpi=300)

        
        with tempfile.TemporaryDirectory() as temp_dir:
            temp_pdf_paths = []

            for i, image in enumerate(images):
                temp_pdf_path = os.path.join(temp_dir, f"{i}.pdf")
                pdf_bytes = pytesseract.image_to_pdf_or_hocr(image, extension='pdf')

                with open(temp_pdf_path, 'wb') as f:
                    f.write(pdf_bytes)

                temp_pdf_paths.append(temp_pdf_path)

            
            merger = PdfMerger()
            for pdf_path in temp_pdf_paths:
                merger.append(pdf_path)
            merger.write(output_path)
            merger.close()

        print(f"Saved to {output_path}")

    except Exception as e:
        print(f"Failed to OCR {filename}: {e}")

# %%
## Confirming how much files are there in the 'ocr_pdfs' folder after the correction : 

path = r"\Dataa\ocr_pdfs"
pdfs = [f for f in os.listdir(path) if f.endswith(".pdf")]
print(f"Leaflets pdf count: {len(pdfs)}")
# Out:
# Leaflets pdf count: 171

# %%
## Confirming how much pdfs are there in the 'selectable_pdfs' folder after the correction : 

path = r"\Dataa\selectable_pdfs"
pdfs = [f for f in os.listdir(path) if f.endswith(".pdf")]
print(f"leaflets pdf count: {len(pdfs)}")

## Now the the numbers addition will give us 1921 medication leaflets pdfs
# Out:
# leaflets pdf count: 1750

# %%
"""
Step 3: Converting OCR-processed and selectable PDFs into clean Markdown (.md) files using Docling.
Outputs are saved in: /extracted_txt_docling
"""

import os
from docling.document_converter import DocumentConverter

# Defining input and output directories
input_dirs = [
    r"\Dataa\ocr_pdfs",
    r"\Dataa\selectable_pdfs"
]
output_dir = r"\Dataa\extracted_txt_docling"
os.makedirs(output_dir, exist_ok=True)

# Initializing the Docling converter
converter = DocumentConverter()

# Processing all PDFs in both input directories


for input_dir in input_dirs:
    print(f"scanning directory: {input_dir}")
    for filename in os.listdir(input_dir):
        if filename.lower().endswith(".pdf"):
            pdf_path = os.path.join(input_dir, filename)
            txt_path = os.path.join(output_dir, filename.replace(".pdf", ".md"))

            print(f"Converting: {filename}")
            try:
                result = converter.convert(pdf_path)
                doc_text = result.document.export_to_markdown()

                with open(txt_path, "w", encoding="utf-8") as f:
                    f.write(doc_text)

                print(f"Saved: {txt_path}")
              

            except Exception as e:
                print(f"Error processing {filename}: {e}")

# %%
## Confirming the final number of the .md files that will be used as the input data for the RAG systems: 

final_files = r"\Dataa\extracted_txt_docling"
md_path= [f for f in os.listdir(final_files) if f.endswith(".md")]
print(f"Final leaflet files count: {len(md_path)}")
# Out:
# Final leaflet files count: 1921
